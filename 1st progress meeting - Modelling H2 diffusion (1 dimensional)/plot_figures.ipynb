# %% [markdown]
# We present here the solution of a simple 1D diffusion problem, Fig. 1, which we can compare with the analytical solution. We consider that all H resides in lattice sites, i.e there are no traps and $\bar{C} = \bar{C}_L$. Fig. 1 shows a bar of length $l = 50 mm$. $\bar{C}_L = 0$ throughout the bar and at time $t = 0$ the concentration at one end is increased to $100 mol/m^3$. Fig. 1 shows the full transient solution.
#
#
# The governing equation for this problem is well known as well as the analytic solution:
#
# $$\frac{\partial \bar{C}_L^2}{\partial x^2} = \frac{1}{D_L} \frac{\partial \bar{C}_L}{\partial t} \quad \text{Eq. 26}$$
#
# The analytic solution reads:
#
# $$\bar{C}_L(x, t) = \bar{C}_0 + \frac{x}{l} (\bar{C}_l - \bar{C}_0) + \sum_{n=1}^{\infty} c_n exp\left(-\frac{n^2 \pi^2 D_L t}{l^2}\right) \sin\left(\frac{n \pi x}{l}\right) \quad \text{Eq. 27}$$
#
# and the Fourier series coefficient is given by:
#
# $$ c_n = \frac{2}{l} \int_{0}^{l} f(x) \sin \left( \frac{n\pi x}{l} \right) dx + \frac{2}{n\pi} \left[ -1^n (\bar{C}_l - \bar{C}_0) \right ] \quad \text{Eq. 28}$$
#
#
# Eq. (26) is essentially a simplified version of (19) in which the term $\frac{\partial \bar{C}}{\partial \bar{C}_L} = 0$ and the last two terms of (19) are zero.
#
# Eq. (26) is implemented in UMATHT by simply coding the following terms:
#
# $$\dfrac{\partial \bar{C}}{\partial \bar{C}_L} = 1 \quad \text{Eq. 29}$$
#
# $$\dfrac{\partial \mathbf{\bar{J}}_m}{\partial (\nabla \bar{C}_L)} = -D_L \mathbf{I} \quad \text{Eq. 30}$$
#
# Fig. 1 shows the transient hydrogen concentration distribution along the bar for both the analytical and computational solution.
#
#
# The value of diffusivity is $D_L = 3.8 \times 10^{-11} m^2/s$ and the computations were conducted using quadratic continuum coupled temperature-displacements hybrid element i.e. CPE8HT. The characteristic time for diffusion (i.e. time necessary for hydrogen to diffuse along the bar) can be determined by using the well known relation
#
# $t = \frac{l^2}{D_L} = (0.05 m)^2 / (3.8 \times 10^{-11} m^2/s) = 65789473 s$
#
# The paper considers a fixed time step of $dt = 1 \times 10^4 s$ and a total time of $t = 1 \times 10^6 s$.
#
# The Abaqus results almost perfectly agree with the analytic solution.

# %%
import numpy as np
import matplotlib.pyplot as plt

D_L = 3.8e-11  # Diffusivity in m^2/s
l = 0.05  # Length of the bar in m
Cbar_0 = 0  # Initial concentration at x=0 in mol/m^3
Cbar_l = 100  # Concentration at one end (x=l) in mol/m^3
n_Fourier_terms = 1000  # Number of terms in the Fourier series for accuracy
               # In the equation it is an infinite series, but we will use a finite number of terms

def calculate_c_n(x, n):
    fx = np.zeros_like(x)
    term1 = 2/l * np.trapz(fx * np.sin(n * np.pi * x / l), x)
    term2 = 2/(n * np.pi) * ((-1)**n * (Cbar_l - Cbar_0))
    return term1 + term2

# Function to calculate Cbar_L(x, t) using the analytical solution
def Cbar_L(x, t):
    """
    x: array of linearly spacing position on the bar in meters from 0 to l => x/l is from 0 to 1
    t: scalar value, time in seconds
    """
    sum_series = np.zeros_like(x)
    #previous_x = np.zeros_like(x)
    for n in range(1, n_Fourier_terms + 1):
        c_n = calculate_c_n(x, n)
        sum_series += c_n * np.exp(- (n**2 * np.pi**2 * D_L * t) / (l**2)) * np.sin((n * np.pi * x) / l)
        # previous_x = term
    Cbar_L_term = Cbar_0 + (x / l) * (Cbar_l - Cbar_0) + sum_series
    return Cbar_L_term

x_values = np.linspace(0, l, 1000)

dt = 10**4 # s
total_time = 10**6 # s
t_diffused_all_bar = l**2/D_L
print(t_diffused_all_bar)
times = [3e4, 3e5, 6e5, 9e5, 12e5, 15e5, 17e5, 19e5, 21e5, 23e5, 25e5]#, 3e5, 4e5, 5e5, 6e5, 7e5, 8e5, 9e5, 25e5, t_diffused_all_bar]
alpha_color = [1.0, 1.0, 0.9, 0.9, 0.8, 0.8, 0.7, 0.7, 0.6, 0.6, 0.5] 
linewidth_list = [2, 2, 1.75, 1.75, 1.5, 1.5, 1.25, 1.25, 1, 1, 1]
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

for i, t in enumerate(times):
    Cbar_L_values = Cbar_L(x_values, t)
    ax[0].plot(x_values / l, Cbar_L_values, label=f't = {t} s', color="red", linewidth=linewidth_list[i], alpha=alpha_color[i])

ax[0].set_xlabel('x/l', fontsize=12)
ax[0].set_ylabel(r'$\bar{C}_L(x, t)$ (mol/m$^3$)', fontsize=12)
ax[0].set_title('Transient Concentration of H in a Bar', fontsize=12)
ax[0].set_yticks(np.arange(0, 110, 10))
ax[0].set_xticks(np.arange(0, 1.1, 0.1))
ax[0].tick_params(axis='both', which='major', labelsize=10)
ax[0].grid(True)

ax[1].axis('off')
ax[1].plot([],[], color="white", label="Plotted times (smallest to largest)\n")
for i, t in enumerate(times):
    ax[1].plot([],[], label=f't = {t} s', color="red", linewidth=linewidth_list[i], alpha=alpha_color[i])

ax[1].legend(loc='center', fontsize=10, frameon=False)
# Out:
# 65789473.68421054

# %%
x_values = np.linspace(0, l, 1000)

dt = 10**4 # s
total_time = 10**6 # s
t_diffused_all_bar = l**2/D_L
print(t_diffused_all_bar)
times = [50e5, 100e5, 150e5, 200e5, round(t_diffused_all_bar)]#, 3e5, 4e5, 5e5, 6e5, 7e5, 8e5, 9e5, 25e5, t_diffused_all_bar]
alpha_color = [1.0, 1.0, 0.9, 0.9, 0.8, 0.8] 
linewidth_list = [2, 2, 1.75, 1.75, 1.5, 1.5]
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

for i, t in enumerate(times):
    Cbar_L_values = Cbar_L(x_values, t)
    ax[0].plot(x_values / l, Cbar_L_values, label=f't = {t} s', color="red", linewidth=linewidth_list[i], alpha=alpha_color[i])

ax[0].set_xlabel('x/l', fontsize=12)
ax[0].set_ylabel(r'$\bar{C}_L(x, t)$ (mol/m$^3$)', fontsize=12)
ax[0].set_title('Transient Concentration of H in a Bar', fontsize=12)
ax[0].set_yticks(np.arange(0, 110, 10))
ax[0].set_xticks(np.arange(0, 1.1, 0.1))
ax[0].tick_params(axis='both', which='major', labelsize=10)
ax[0].grid(True)

ax[1].axis('off')
ax[1].plot([],[], color="white", label="Plotted times (smallest to largest)\n")
for i, t in enumerate(times):
    ax[1].plot([],[], label=f't = {t} s', color="red", linewidth=linewidth_list[i], alpha=alpha_color[i])

ax[1].legend(loc='center', fontsize=10, frameon=False)
# Out:
# 65789473.68421054

# %%
x_values = np.linspace(0, l, 1000)

dt = 10**4 # s
total_time = 10**6 # s
t_diffused_all_bar = l**2/D_L
print(t_diffused_all_bar)
times = [1e6]#, 3e5, 4e5, 5e5, 6e5, 7e5, 8e5, 9e5, 25e5, t_diffused_all_bar]
alpha_color = [1.0] 
linewidth_list = [2]
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

for i, t in enumerate(times):
    Cbar_L_values = Cbar_L(x_values, t)
    ax[0].plot(x_values / l, Cbar_L_values, label=f't = {t} s', color="red", linewidth=linewidth_list[i], alpha=alpha_color[i])

ax[0].set_xlabel('x/l', fontsize=12)
ax[0].set_ylabel(r'$\bar{C}_L(x, t)$ (mol/m$^3$)', fontsize=12)
ax[0].set_title('Transient Concentration of H in a Bar', fontsize=12)
ax[0].set_yticks(np.arange(0, 110, 10))
ax[0].set_xticks(np.arange(0, 1.1, 0.1))
ax[0].tick_params(axis='both', which='major', labelsize=10)
ax[0].grid(True)

ax[1].axis('off')
ax[1].plot([],[], color="white")#, label="Plotted times (smallest to largest)\n")
for i, t in enumerate(times):
    ax[1].plot([],[], label=f't = {t} s', color="red", linewidth=linewidth_list[i], alpha=alpha_color[i])

ax[1].legend(loc='center', fontsize=10, frameon=False)
# Out:
# 65789473.68421054
